# %%
import pandas as pd

# Read the Excel file
file_path = r"d:\Policeproject\traffic_stops.xlsx"
Policecheck_df = pd.read_excel(file_path)

# Display first few rows
Policecheck_df.head()
# Out:
#    stop_date stop_time country_name driver_gender  driver_age_raw  driver_age  \
# 0 2020-01-01  00:00:00       Canada             M              59          19
# 1 2020-01-01  00:01:00        India             M              35          58
# 2 2020-01-01  00:02:00          USA             M              26          76
# 3 2020-01-01  00:03:00       Canada             M              26          76
# 4 2020-01-01  00:04:00       Canada             M              62          75
#
#   driver_race     violation_raw violation  search_conducted     search_type  \
# 0       Asian     Drunk Driving  Speeding              True  Vehicle Search
# 1       Other             Other     Other             False  Vehicle Search
# 2       Black  Signal Violation  Speeding             False           Frisk
# 3       Black          Speeding       DUI              True           Frisk
# 4       Other          Speeding     Other             False  Vehicle Search
#
# ...

# %%
print(Policecheck_df.isnull().sum())
# Out:
# stop_date                 0
# stop_time                 0
# country_name              0
# driver_gender             0
# driver_age_raw            0
# driver_age                0
# driver_race               0
# violation_raw             0
# violation                 0
# search_conducted          0
# search_type           21720
# stop_outcome              0
# is_arrested               0
# stop_duration             0
# drugs_related_stop        0
# vehicle_number            0
# dtype: int64

# %%
Cleaned_Policecheck= Policecheck_df.fillna(df.mode().iloc[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 Cleaned_Policecheck= Policecheck_df.fillna(df.mode().iloc[0])
#
# NameError: name 'df' is not defined

# %%
df_mode = Policecheck_df.fillna(df.mode().iloc[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df_mode = Policecheck_df.fillna(df.mode().iloc[0])
#
# NameError: name 'df' is not defined

# %%
df_zero = Policecheck_df.fillna(0)

# %%
print(df_zero.isnull().sum())
# Out:
# stop_date             0
# stop_time             0
# country_name          0
# driver_gender         0
# driver_age_raw        0
# driver_age            0
# driver_race           0
# violation_raw         0
# violation             0
# search_conducted      0
# search_type           0
# stop_outcome          0
# is_arrested           0
# stop_duration         0
# drugs_related_stop    0
# vehicle_number        0
# dtype: int64

# %%
Cleaned_Policecheck.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 Cleaned_Policecheck.head(50)
#
# NameError: name 'Cleaned_Policecheck' is not defined

# %%
import mysql.connector

conn_mysql = mysql.connector.connect(
    host="localhost",
    user="root",
    password="usha"
)
cursor_mysql = conn_mysql.cursor()
print("MySQL connection established!")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import mysql.connector

conn_mysql = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Usha"
)
cursor_mysql = conn_mysql.cursor()
print("MySQL connection established!")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import mysql.connector

conn_mysql = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Usha"
)
cursor_mysql = conn_mysql.cursor()
print("MySQL connection established!")

# %%
import pymysql

mydb = pymysql.connect(
  host="localhost",
  user="root",
  password="usha"
  
  
)

mycursor = mydb.cursor()

# %%
# !pip install pymysql

# %%
mycursor.execute("CREATE DATABASE Securecheck")
# Out:
# 1

# %%
mycursor.execute("SHOW DATABASES")
for x in mycursor:
  print(x)
# Out:
# ('db1',)
# ('dsp',)
# ('dte38',)
# ('dte39',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('securecheck',)
# ('sys',)
# ('world',)

# %%
mycursor.execute("use Securecheck")
# Out:
# 0

# %%
mycursor.execute("""
    CREATE TABLE IF NOT EXISTS Policelog_data (
      stop_date  DATE,
      stop_time TIME,
      country_name  VARCHAR(50),
      driver_gender VARCHAR(10),
      driver_age_raw int,
      driver_age int,
      driver_race VARCHAR(50),
      violation_raw  VARCHAR(250),
      violation VARCHAR(50),
      search_conducted BOOLEAN,
      search_type VARCHAR(50),
      stop_outcome VARCHAR(50),
      is_arrested BOOLEAN,
      stop_duration int,
      drugs_related_stop BOOLEAN,
      vehicle_number  VARCHAR(50)


    );
""")
# Out:
# 0

# %%
insert_query = """
    INSERT INTO Policelog_data (stop_date,stop_time,country_name,driver_gender,driver_age_raw,driver_age,driver_race,violation_raw, violation,search_conducted,search_type ,
      stop_outcome ,is_arrested,stop_duration,drugs_related_stop,vehicle_number)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s,%s,%s,%s,%s,%s,%s);
"""
cursor_mysql.executemany(query,df.values.tolist())
conn_mysql.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 6
#       1 insert_query = """
#       2     INSERT INTO Policelog_data (stop_date,stop_time,country_name,driver_gender,driver_age_raw,driver_age,driver_race,violation_raw, violation,search_conducted,search_type ,
#       3       stop_outcome ,is_arrested,stop_duration,drugs_related_stop,vehicle_number)
#       4     VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s,%s,%s,%s,%s,%s,%s);
#       5 """
# ----> 6 cursor_mysql.executemany(query,df.values.tolist())
#       7 conn_mysql.commit()
#
# NameError: name 'cursor_mysql' is not defined

# %%
insert_query = """
    INSERT INTO Policelog_data (
        stop_date, stop_time, country_name, driver_gender,
        driver_age_raw, driver_age, driver_race, violation_raw,
        violation, search_conducted, search_type, stop_outcome,
        is_arrested, stop_duration, drugs_related_stop, vehicle_number
    )
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
"""
mycursor.executemany(insert_query,df.values.tolist())
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 10
#       1 insert_query = """
#       2     INSERT INTO Policelog_data (
#       3         stop_date, stop_time, country_name, driver_gender,
#    (...)
#       8     VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
#       9 """
# ---> 10 mycursor.executemany(insert_query,df.values.tolist())
#      11 mydb.commit()
#
# NameError: name 'df' is not defined

# %%
query = """
    INSERT INTO Policelog_data (
        stop_date, stop_time, country_name, driver_gender,
        driver_age_raw, driver_age, driver_race, violation_raw,
        violation, search_conducted, search_type, stop_outcome,
        is_arrested, stop_duration, drugs_related_stop, vehicle_number
    )
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
"""

cursor_mysql.executemany(query, df.values.tolist())
conn_mysql.commit()
print("Data inserted using executemany()")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 11
#       1 query = """
#       2     INSERT INTO Policelog_data (
#       3         stop_date, stop_time, country_name, driver_gender,
#    (...)
#       8     VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
#       9 """
# ---> 11 cursor_mysql.executemany(query, df.values.tolist())
#      12 conn_mysql.commit()
#      13 print("Data inserted using executemany()")
#
# NameError: name 'cursor_mysql' is not defined

# %%
import pandas as pd
# SQL query
query = """
    INSERT INTO Policelog_data (
        stop_date, stop_time, country_name, driver_gender,
        driver_age_raw, driver_age, driver_race, violation_raw,
        violation, search_conducted, search_type, stop_outcome,
        is_arrested, stop_duration, drugs_related_stop, vehicle_number
    )
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
"""

# Replace NaN with None for MySQL


# Execute and commit
mycursor.executemany(query,df.values.tolist())
mydb.commit()

print("Data inserted using executemany()")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 17
#       3 query = """
#       4     INSERT INTO Policelog_data (
#       5         stop_date, stop_time, country_name, driver_gender,
#    (...)
#      10     VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
#      11 """
#      13 # Replace NaN with None for MySQL
#      14
#      15
#      16 # Execute and commit
# ---> 17 mycursor.executemany(query,df.values.tolist())
#      18 mydb.commit()
#      20 print("Data inserted using executemany()")
#
# NameError: name 'df' is not defined

# %%
Cleaned_Policecheck = Policecheck_df.fillna(df.mode().iloc[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 Cleaned_Policecheck = Policecheck_df.fillna(df.mode().iloc[0])
#
# NameError: name 'Policecheck_df' is not defined

# %%
query = """
    INSERT INTO Policelog_data (
        stop_date, stop_time, country_name, driver_gender,
        driver_age_raw, driver_age, driver_race, violation_raw,
        violation, search_conducted, search_type, stop_outcome,
        is_arrested, stop_duration, drugs_related_stop, vehicle_number
    )
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
"""

# %%
import pandas as pd

# Read the Excel file
file_path = r"d:\Policeproject\traffic_stops.xlsx"
Policecheck_df = pd.read_excel(file_path)

# Display first few rows
Policecheck_df.head()
# Out:
#    stop_date stop_time country_name driver_gender  driver_age_raw  driver_age  \
# 0 2020-01-01  00:00:00       Canada             M              59          19
# 1 2020-01-01  00:01:00        India             M              35          58
# 2 2020-01-01  00:02:00          USA             M              26          76
# 3 2020-01-01  00:03:00       Canada             M              26          76
# 4 2020-01-01  00:04:00       Canada             M              62          75
#
#   driver_race     violation_raw violation  search_conducted     search_type  \
# 0       Asian     Drunk Driving  Speeding              True  Vehicle Search
# 1       Other             Other     Other             False  Vehicle Search
# 2       Black  Signal Violation  Speeding             False           Frisk
# 3       Black          Speeding       DUI              True           Frisk
# 4       Other          Speeding     Other             False  Vehicle Search
#
# ...

# %%
Policecheck_df = Policecheck_df.where(pd.notnull(Policecheck_df), None)

# %%
Policecheck_df.head(50)
# Out:
#     stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0  2020-01-01  00:00:00       Canada             M              59
# 1  2020-01-01  00:01:00        India             M              35
# 2  2020-01-01  00:02:00          USA             M              26
# 3  2020-01-01  00:03:00       Canada             M              26
# 4  2020-01-01  00:04:00       Canada             M              62
# 5  2020-01-01  00:05:00       Canada             F              44
# 6  2020-01-01  00:06:00          USA             F              80
# 7  2020-01-01  00:07:00        India             M              72
# 8  2020-01-01  00:08:00          USA             F              80
# 9  2020-01-01  00:09:00          USA             M              43
# 10 2020-01-01  00:10:00        India             F              66
# 11 2020-01-01  00:11:00       Canada             F              58
# 12 2020-01-01  00:12:00        India             M              51
# ...

# %%
Cleaned_df = Policecheck_df.fillna(Policecheck_df.mode().iloc[0])

# %%
Cleaned_df.head(50)
# Out:
#     stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0  2020-01-01  00:00:00       Canada             M              59
# 1  2020-01-01  00:01:00        India             M              35
# 2  2020-01-01  00:02:00          USA             M              26
# 3  2020-01-01  00:03:00       Canada             M              26
# 4  2020-01-01  00:04:00       Canada             M              62
# 5  2020-01-01  00:05:00       Canada             F              44
# 6  2020-01-01  00:06:00          USA             F              80
# 7  2020-01-01  00:07:00        India             M              72
# 8  2020-01-01  00:08:00          USA             F              80
# 9  2020-01-01  00:09:00          USA             M              43
# 10 2020-01-01  00:10:00        India             F              66
# 11 2020-01-01  00:11:00       Canada             F              58
# 12 2020-01-01  00:12:00        India             M              51
# ...

# %%
insert_query = """
    INSERT INTO Policelog_data (
        stop_date, stop_time, country_name, driver_gender,
        driver_age_raw, driver_age, driver_race, violation_raw,
        violation, search_conducted, search_type, stop_outcome,
        is_arrested, stop_duration, drugs_related_stop, vehicle_number
    )
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
"""
mycursor.executemany(insert_query,Cleaned_df.values.tolist())
mydb.commit()

# %%
mycursor.execute("""
    ALTER TABLE Policelog_data
    MODIFY COLUMN stop_duration VARCHAR(50);
""")
# Out:
# 0

# %%
mycursor.execute("""
    ALTER TABLE Policelog_data
    MODIFY COLUMN vehicle_number VARCHAR(50);
""")
mydb.commit()
